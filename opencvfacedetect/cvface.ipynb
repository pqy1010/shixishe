# %%
import numpy as np
import argparse
import cv2
from matplotlib import pyplot as plt

# %%
net = cv2.dnn.readNetFromCaffe('deploy.prototxt.txt', 'res10_300x300_ssd_iter_140000.caffemodel')

# %%
imgdata=cv2.imread('bbbb.jpeg')
img2 = imgdata[:,:,::-1] # 必须为 ::-1
plt.imshow(img2)

# %%
(h, w) = imgdata.shape[:2]
blob = cv2.dnn.blobFromImage(cv2.resize(imgdata, (300, 300)), 1.0,
	(300, 300), (104.0, 177.0, 123.0))

# %%
a=blob[1:]
b=a.transpose(1,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-5919344d3d79> in <module>
#       1 a=blob[1:]
# ----> 2 b=a.transpose(1,2)
#
# ValueError: axes don't match array

# %%
net.setInput(blob)
detections = net.forward()
